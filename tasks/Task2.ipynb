# %% [markdown]
# ### Задание №1
# Массив A состоит из целых положительных чисел длин отрезков. Составьте из трех отрезков такой треугольник, чтобы его периметр был максимально возможным. Если невозможно составить треугольник с положительной площадью функция возвращает 0.

# %%
A = [[2,5,6,7],[4,6,9,4],[2,5,9,10],[11,24,32,1]]
maxsi = []
for i in A:
    maxsi.append(max(i))
if len(maxsi)>2:
    print(maxsi.pop(maxsi.index(max(maxsi)))+maxsi.pop(maxsi.index(max(maxsi)))+maxsi.pop(maxsi.index(max(maxsi))))
else:
    print(0)

# %% [markdown]
# ### Задание №2
# Дан массив неотрицательных целых чисел nums. Расположите их в таком порядке, чтобы вместе они образовали максимально возможное число. Замечание: Результат может быть очень большим числом, поэтому представьте его как string, а не integer.

# %%
nums = [5,4,7,92,3,9,0,63,75,8,46,25,35,60,10,31,12]
sp9=[]
sp8=[]
sp7=[]
sp6=[]
sp5=[]
sp4=[]
sp3=[]
sp2=[]
sp1=[]
sp0=[]
for i in nums:
    if i == 9 or str(i)[0] == "9":
        sp9.append(str(i))
    elif i == 8 or str(i)[0] == "8":
        sp8.append(str(i))
    elif i == 7 or str(i)[0] == "7":
        sp7.append(str(i))
    elif i == 6 or str(i)[0] == "6":
        sp6.append(str(i))
    elif i == 5 or str(i)[0] == "5":
        sp5.append(str(i))
    elif i == 4 or str(i)[0] == "4":
        sp4.append(str(i))
    elif i == 3 or str(i)[0] == "3":
        sp3.append(str(i))
    elif i == 2 or str(i)[0] == "2":
        sp2.append(str(i))
    elif i == 1 or str(i)[0] == "1":
        sp1.append(str(i))
    else:
        sp0.append(str(i))
sp = [sp9,sp8,sp7,sp6,sp5,sp4,sp3,sp2,sp1,sp0]
for k in range(len(sp)):
    o = 0
    if len(sp[k])>0:
        for i in range(len(sp[k])-1):
            if int(str(sp[k][i])+str(sp[k][i+1]))>int(str(sp[k][i+1])+str(sp[k][i])):
                pass
            else:
                o = sp[k][i]
                sp[k][i]=sp[k][i+1]
                sp[k][i+1]=o
otv = ""
for i in sp:
    for y in i:
        otv+=str(y)
print(otv)

# %% [markdown]
# ### Задание №3
# Дана матрица mat размером m * n, значения целочисленные. Напишите функцию, сортирующую каждую диагональ матрицы по возрастанию и возвращающую получившуюся матрицу.

# %%
mat = [[2,6,4,7],[5,7,8,9],[5,6,0,2],[5,7,8,9]]
m=len(mat)
n = len(mat[0])
deag = m+n-1
m1=m
n1=n
ch=0
da=[]
mas=[]
"""for i in range(m):
    for ii in range(n):
        print(mat[i][ii],end=" ")
    print("")"""
if deag%2==0:
    if n>m:
        while m1>0:
            for i in range(m1):
                da.append(mat[i+(m-m1)][i])
            mas.append(da)
            da=[]
            m1-=1
        n1-=1
        while n1>0:
            for i in range(n1):
                da.append(mat[i][i+(n-n1)])
            mas.append(da)
            da=[]
            n1-=1
    else:
        while n1>0:
            for i in range(n1):
                da.append(mat[i][i+(n-n1)])
            mas.append(da)
            da=[]
            n1-=1
        m1-=1
        while m1>0:
            for i in range(m1):
                da.append(mat[i+(m-m1)][i])
            mas.append(da)
            da=[]
            m1-=1
else:
    for i in range(m):
        da.append(mat[i][i])
    mas.append(da)
    da=[]
    m1-=1
    while m1>0:
        for i in range(m1):
            da.append(mat[i][i+(m-m1)])
        mas.append(da)
        da=[]
        m1-=1
    n1-=1
    while n1>0:
        for i in range(n1):
            da.append(mat[i+(n-n1)][i])
        mas.append(da)
        da=[]
        n1-=1
for i in mas:
    i.sort()
m2=m
n2=n
if deag%2==0:
    if n>m:
        while m2>0:
            for i in range(m2):
                mat[i+(m-m2)][i] = mas[m-m2][i]
            m2-=1
        n2-=1
        while n2>0:
            print(n,n2)
            for i in range(n2):
                mat[i][i+(n-n2)] = mas[m+(n-n2)-1][i]
            n2-=1
    else:
        while n2>0:
            for i in range(n2):
                mat[i][i+(n-n2)]= mas[n-n2][i]
            n2-=1
        m2-=1
        while m2>0:
            for i in range(m2):
                mat[i+(m-m2)][i] = mas[n+(m-m2)-1][i]
            m2-=1
else:
    for i in range(m):
        mat[i][i] = mas[0][i]

    m2-=1
    while m2>0:
        for i in range(m2):
            mat[i][i+(m-m2)] = mas[m-m2][i]
        m2-=1
    n2-=1
    while n2>0:
        for i in range(n2):
            mat[i+(n-n2)][i]= mas[m+(n-n2)-1][i]
        n2-=1
for i in range(m):
    for ii in range(n):
        print(mat[i][ii],end=" ")
    print("")
